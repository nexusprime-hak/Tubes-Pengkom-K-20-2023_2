# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_1 = pd.read_csv('vgsales.csv')
df_1 = df_1.drop(columns="Rank")

# %% [markdown]
# <h5>Dataframe yang dipakai:

# %%
df_1
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# <h1>Sampel Data</h1>
# <p>Ada banyak metode sampling yang dapat digunakan dalam mengolah suatu data. Dalam tugas kali ini, kami akan menggunakan beberapa metode berikut:</p>
# <ol>
# <li>Systematic Sampling</li>
#     <p>Systematic sampling mengelompokkan datapoints dengan suatu sistematika tertentu. Misalnya 10 data pertama, data terbesar, dan data terkecil.</p>
# <li>Stratified Sampling</li>
#     <p>Stratified Sampling mengelompokkan setiap datapoints ke dalam tiap-tiap strata. Strata yang dipakai ditentukan oleh setiap dataframe</p>
# </ol>

# %% [markdown]
# <h3>Systematic Sampling: Dataframe 1</h3>
# <p>Pada sampling ini, akan diberikan data 10 game pertama dengan penjualan global paling banyak</p>

# %%
max_10 = df_1.sort_values(by='Global_Sales', ascending=False)
max_10.head(10)
# Out:
#                         Name Platform    Year         Genre Publisher  \
# 0                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# ...

# %% [markdown]
# <p>Pada sampling ini akan diberikan 10 data pertama game dengan penjualan global paling sedikit</p>

# %%
min_10 = df_1.sort_values(by='Global_Sales', ascending=True)
min_10.head(10)
# Out:
#                                                   Name Platform    Year  \
# 16597                                 Spirits & Spells      GBA  2003.0
# 16188                                 Toro to Morimori      PS3  2009.0
# 16187                                   Jewel Quest II       PC  2007.0
# 16186                                      BattleForge       PC  2009.0
# 16185           Tantei Jinguuji Saburo: Hai to Diamond      PSP  2009.0
# 16184  Fatal Fury: Battle Archives Volume 2 (JP sales)      PS2  2007.0
# 16183                      Sakura-Sou no Pet na Kanojo      PSP  2013.0
# 16182                                  Princess Arthur      PSP  2013.0
# 16181                             Resistance Dual Pack      PS3  2011.0
# 16180                        Rozen Maiden: Gebetgarten      PS2  2007.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16597   Platform                      Wanadoo      0.01      0.00      0.00
# ...

# %% [markdown]
# <h3>Stratified Sampling: Dataframe 1</h3>
# <h4>Dataframe 1 akan dikelompokkan ke dalam beberapa kelompok</h4>

# %% [markdown]
# <h5>Strata 1: Distribusi frekuensi platform game</h5>

# %% [markdown]
# <p>Dari kode di bawah dapat diperoleh distribusi frekuensi platform atau konsol game yang dimiliki oleh para konsumen game. Diketahui bahwa platform game terbanyak adalah Nintendo DS dan yang paling sedikit adalah SEGA Game Gear.</p>

# %%
platform = df_1.sort_values(by="Platform")
platform_strat = platform.drop(columns=["Year","Genre","Publisher","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"])
platform_strat = platform_strat.groupby(by="Platform").count().sort_values(by="Name", ascending=False)
platform_strat.rename(columns={"Name":"Console_Count"})
# Out:
#           Console_Count
# Platform
# DS                 2163
# PS2                2161
# PS3                1329
# Wii                1325
# X360               1265
# PSP                1213
# PS                 1196
# PC                  960
# XB                  824
# GBA                 822
# GC                  556
# 3DS                 509
# PSV                 413
# PS4                 336
# N64                 319
# SNES                239
# XOne                213
# SAT                 173
# WiiU                143
# 2600                133
# NES                  98
# GB                   98
# DC                   52
# GEN                  27
# NG                   12
# SCD                   6
# WS                    6
# 3DO                   3
# TG16                  2
# PCFX                  1
# GG                    1

# %% [markdown]
# Dari tabel di atas diperoleh jumlah game yang berkorespondensi dengan platform dari game tersebut. Platform dengan jumlah game <b>terbanyak</b> adalah Nintendo DS, sedangkan platform dengan jumlah game <b>paling sedikit</b> adalah SEGA Game Gear.

# %% [markdown]
# <h5>Strata 2: Genre game berdasarkan jumlah penjualannya</h5>

# %% [markdown]
# Pertama kita kelompokkan data berdasarkan genre game.

# %%
genre = df_1[["Genre","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]]
genre_strat = genre.groupby(by="Genre")

# %% [markdown]
# Jumlah rilisan game untuk setiap genre berdasarkan dataframe:

# %%
genre_strat.count().filter(items=["Global_Sales"]).rename(columns={"Global_Sales":"Games_Count"})
# Out:
#               Games_Count
# Genre
# Action               3316
# Adventure            1286
# Fighting              848
# Misc                 1739
# Platform              886
# Puzzle                582
# Racing               1249
# Role-Playing         1488
# Shooter              1310
# Simulation            867
# Sports               2346
# Strategy              681

# %% [markdown]
# Jumlah salinan game yang terjual untuk setiap genrenya pada setiap region:

# %%
genre_strat.sum()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action          877.83    525.00    159.95       187.38       1751.18
# Adventure       105.80     64.13     52.07        16.81        239.04
# Fighting        223.59    101.32     87.35        36.68        448.91
# Misc            410.24    215.98    107.76        75.32        809.96
# Platform        447.05    201.63    130.77        51.59        831.37
# Puzzle          123.78     50.78     57.31        12.55        244.95
# Racing          359.42    238.39     56.69        77.27        732.04
# Role-Playing    327.28    188.06    352.31        59.61        927.37
# Shooter         582.60    313.27     38.28       102.69       1037.37
# Simulation      183.31    113.38     63.70        31.52        392.20
# Sports          683.35    376.85    135.37       134.97       1330.93
# Strategy         68.70     45.34     49.46        11.36        175.12

# %% [markdown]
# <h5>Strata 3: Publisher Game</h5> <br>
# Data dikelompokkan berdasarkan publisher dari game tersebut. Lalu jumlah salinan setiap game yang dibuat oleh studio game tersebut kita jumlahkan dengan method sum() untuk meninjau berapa banyak salinan game yang telah dijual oleh setiap studio tersebut.

# %%
pub = df_1[["Publisher","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]]
pub = pub.groupby(by="Publisher")

# %% [markdown]
# Setelah itu kita dapat melihat beberapa data statistik, seperti:

# %%
# distribusi frekuensi
pub.count().filter(items=["Global_Sales"]).sort_values(by="Global_Sales", ascending=False).rename(columns={"Global_Sales":"Games_Count"})
# Out:
#                               Games_Count
# Publisher
# Electronic Arts                      1351
# Activision                            975
# Namco Bandai Games                    932
# Ubisoft                               921
# Konami Digital Entertainment          832
# ...                                   ...
# Playmates                               1
# Playmore                                1
# Plenty                                  1
# Pony Canyon                             1
# SCS Software                            1
#
# [578 rows x 1 columns]

# %%
# 10 studio dengan rilisan game paling banyak berdasarkan dataframe
pub_10_top = pub.count().filter(items=["Global_Sales"]).sort_values(by="Global_Sales", ascending=False).head(10)
pub_10_top.rename(columns={"Global_Sales":"Games_Count"})
# Out:
#                               Games_Count
# Publisher
# Electronic Arts                      1351
# Activision                            975
# Namco Bandai Games                    932
# Ubisoft                               921
# Konami Digital Entertainment          832
# THQ                                   715
# Nintendo                              703
# Sony Computer Entertainment           683
# Sega                                  639
# Take-Two Interactive                  413

# %%
# 10 studio dengan rilisan game paling sedikit berdasarkan dataframe
pub_10_bottom = pub.count().filter(items=["Global_Sales"]).sort_values(by="Global_Sales", ascending=False).tail(10)
pub_10_bottom.rename(columns={"Global_Sales":"Games_Count"})
# Out:
#                        Games_Count
# Publisher
# Piacci                           1
# Giga                             1
# Genterprise                      1
# General Entertainment            1
# Gameloft                         1
# Playmates                        1
# Playmore                         1
# Plenty                           1
# Pony Canyon                      1
# SCS Software                     1

# %%
# 10 studio game dengan penjualan game paling sedikit
pub.sum().sort_values(by="Global_Sales",ascending=False).tail(10)
# Out:
#                        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Publisher
# Genterprise                0.00      0.00      0.01          0.0          0.01
# New World Computing        0.01      0.00      0.00          0.0          0.01
# Otomate                    0.00      0.00      0.01          0.0          0.01
# Ascaron Entertainment      0.00      0.01      0.00          0.0          0.01
# Stainless Games            0.01      0.01      0.00          0.0          0.01
# Ongakukan                  0.00      0.00      0.01          0.0          0.01
# Commseed                   0.00      0.00      0.01          0.0          0.01
# Takuyo                     0.00      0.00      0.01          0.0          0.01
# Boost On                   0.00      0.00      0.01          0.0          0.01
# Naxat Soft                 0.00      0.00      0.01          0.0          0.01

# %% [markdown]
# Dari hasil di atas dapat disimpulkan bahwa 10TACLE Studios menjadi studio game dengan nilai penjualan terkecil.

# %%
# 10 studio game  dengan penjualan game terbanyak
pub.sum().sort_values(by="Global_Sales",ascending=False).head(10)
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                        816.87    418.74    455.42        95.33
# Electronic Arts                 595.07    371.27     14.04       129.77
# Activision                      429.70    215.53      6.54        75.34
# Sony Computer Entertainment     265.22    187.72     74.10        80.45
# Ubisoft                         253.43    163.32      7.50        50.26
# Take-Two Interactive            220.49    118.14      5.83        55.24
# THQ                             208.77     94.73      5.01        32.14
# Konami Digital Entertainment     92.16     69.69     91.30        30.31
# Sega                            109.40     82.00     57.03        24.52
# Namco Bandai Games               69.52     42.63    127.07        14.69
#
#                               Global_Sales
# Publisher
# Nintendo                           1786.56
# Electronic Arts                    1110.32
# ...

# %% [markdown]
# <h2>Statistik Data</h2>

# %% [markdown]
# Mari kita tinjau statistik untuk setiap strata yang sudah kita buat di atas.<br><br>
# 1. Strata 1: Platform Game<br>
# <hr>

# %% [markdown]
# 1.1 Rata-rata dan standar deviasi

# %%
platform_mean = platform.drop(columns=['Year','Name','Genre','Publisher'])
platform_mean.groupby(by="Platform").mean().sort_values(by="Global_Sales", ascending=False)
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# GB        1.166531  0.487959  0.868571     0.083673      2.606633
# NES       1.285102  0.215816  1.006633     0.054184      2.561939
# GEN       0.713704  0.204444  0.098889     0.032963      1.050370
# SNES      0.256192  0.079665  0.487657     0.013473      0.837029
# PS4       0.288095  0.368155  0.042560     0.129048      0.827679
# X360      0.475138  0.221802  0.009826     0.067621      0.774672
# 2600      0.681203  0.041128  0.000000     0.006842      0.729925
# PS3       0.295154  0.258623  0.060188     0.106795      0.720722
# Wii       0.383177  0.202551  0.052340     0.060838      0.699404
# N64       0.435799  0.128715  0.107273     0.013730      0.686144
# XOne      0.390563  0.214319  0.001596     0.055962      0.662254
# PS        0.281363  0.178595  0.116906     0.034206      0.610920
# PS2       0.270171  0.157006  0.064415     0.089514      0.581046
# ...

# %% [markdown]
# Data di atas menunjukkan rata-rata jumlah game yang terjual di setiap region yang dikelompokkan berdasarkan platformnya.

# %%
platform_std = platform.drop(columns=['Year','Name','Genre','Publisher'])
platform_std.groupby(by="Platform").std().dropna(axis=0, how='all')
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600      0.854741  0.052867  0.000000     0.010827      0.917241
# 3DO       0.000000  0.000000  0.023094     0.000000      0.023094
# 3DS       0.516286  0.403103  0.515452     0.084982      1.390430
# DC        0.311979  0.116550  0.132539     0.016976      0.469912
# DS        0.537962  0.497925  0.391225     0.128631      1.434616
# GB        3.018756  1.247071  1.401042     0.185858      5.365287
# GBA       0.443121  0.227542  0.267064     0.031134      0.896517
# GC        0.423270  0.142687  0.139695     0.020662      0.685487
# GEN       1.113132  0.317845  0.086128     0.050598      1.492217
# N64       0.797725  0.294827  0.299421     0.029496      1.315965
# NES       4.080581  0.521698  0.968289     0.180748      5.108195
# NG        0.000000  0.000000  0.082241     0.000000      0.082241
# PC        0.354838  0.403351  0.003884     0.072388      0.681493
# ...

# %% [markdown]
# Data di atas menunjukkan standar deviasi dari jumlah game yang terjual di setiap region yang dikelompokkan berdasarkan platformnya.

# %% [markdown]
# 1.2 Ekstremum

# %%
platform_max = platform.drop(columns=['Year','Name','Genre','Publisher'])
platform_max.max(axis=0, skipna=True)
# Out:
# Platform         XOne
# NA_Sales        41.49
# EU_Sales        29.02
# JP_Sales        10.22
# Other_Sales     10.57
# Global_Sales    82.74
# dtype: object

# %% [markdown]
# Dari data di atas, console dengan jumlah game yang terjual paling banyak adalah XBox One.

# %%
platform_min = platform.drop(columns=['Year','Name','Genre','Publisher'])
platform_min.min(axis=0, skipna=True)
# Out:
# Platform        2600
# NA_Sales         0.0
# EU_Sales         0.0
# JP_Sales         0.0
# Other_Sales      0.0
# Global_Sales    0.01
# dtype: object

# %% [markdown]
# Dari data di atas, dapat diketahui bahwa console dengan jumlah game terjual paling sedikit adalah Atari 2600.

# %% [markdown]
# 1.3 Persentil

# %%
platform_quant = platform.drop(columns=['Year','Name','Genre','Publisher']).sort_values(by="Global_Sales")
platform_quant=platform_quant.groupby(by='Platform').quantile([.1,.25,.5,.75,.9], interpolation='nearest')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(platform_quant)
# Out:
#                NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600     0.10      0.20      0.01      0.00         0.00          0.21
#          0.25      0.28      0.02      0.00         0.00          0.29
#          0.50      0.43      0.03      0.00         0.00          0.46
#          0.75      0.72      0.04      0.00         0.01          0.78
#          0.90      1.26      0.08      0.00         0.02          1.36
# 3DO      0.10      0.00      0.00      0.02         0.00          0.02
#          0.25      0.00      0.00      0.02         0.00          0.02
#          0.50      0.00      0.00      0.02         0.00          0.02
#          0.75      0.00      0.00      0.06         0.00          0.06
#          0.90      0.00      0.00      0.06         0.00          0.06
# 3DS      0.10      0.00      0.00      0.00         0.00          0.03
#          0.25      0.00      0.00      0.00         0.00          0.05
# ...

# %%
platform_quant.groupby(by='Platform').quantile(.25, interpolation='nearest')
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          0.28      0.02      0.00         0.00          0.29
# 3DO           0.00      0.00      0.02         0.00          0.02
# 3DS           0.00      0.00      0.00         0.00          0.05
# DC            0.00      0.00      0.07         0.00          0.08
# DS            0.00      0.00      0.00         0.00          0.05
# GB            0.00      0.00      0.23         0.00          0.30
# GBA           0.03      0.01      0.00         0.00          0.06
# GC            0.05      0.01      0.00         0.00          0.07
# GEN           0.00      0.00      0.03         0.00          0.07
# GG            0.00      0.00      0.04         0.00          0.04
# N64           0.06      0.02      0.00         0.00          0.13
# NES           0.04      0.00      0.40         0.00          1.00
# NG            0.00      0.00      0.06         0.00          0.06
# ...

# %%
platform_quant.groupby(by='Platform').quantile(.5, interpolation='nearest')
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          0.43      0.03      0.00         0.00          0.46
# 3DO           0.00      0.00      0.02         0.00          0.02
# 3DS           0.01      0.00      0.05         0.00          0.12
# DC            0.00      0.00      0.12         0.00          0.13
# DS            0.06      0.00      0.00         0.01          0.11
# GB            0.00      0.00      0.40         0.01          1.15
# GBA           0.10      0.04      0.00         0.00          0.16
# GC            0.11      0.03      0.00         0.00          0.15
# GEN           0.00      0.00      0.07         0.00          0.15
# GG            0.00      0.00      0.04         0.00          0.04
# N64           0.18      0.04      0.00         0.00          0.27
# NES           0.40      0.08      0.76         0.01          1.36
# NG            0.00      0.00      0.08         0.00          0.08
# ...

# %%
platform_quant.groupby(by='Platform').quantile(.75, interpolation='nearest')
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          0.72      0.04      0.00         0.01          0.78
# 3DO           0.00      0.00      0.06         0.00          0.06
# 3DS           0.12      0.06      0.14         0.02          0.34
# DC            0.00      0.00      0.22         0.00          0.29
# DS            0.17      0.02      0.03         0.02          0.28
# GB            0.92      0.48      0.92         0.06          2.18
# GBA           0.25      0.09      0.00         0.01          0.39
# GC            0.26      0.07      0.00         0.01          0.35
# GEN           1.03      0.37      0.15         0.05          1.76
# GG            0.00      0.00      0.04         0.00          0.04
# N64           0.45      0.09      0.05         0.01          0.60
# NES           0.77      0.18      1.39         0.03          2.23
# NG            0.00      0.00      0.20         0.00          0.20
# ...

# %%
platform_quant.groupby(by='Platform').quantile(.9, interpolation='higher')
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 2600          1.26      0.08      0.00         0.02          1.36
# 3DO           0.00      0.00      0.06         0.00          0.06
# 3DS           0.31      0.26      0.37         0.05          0.94
# DC            0.41      0.05      0.37         0.02          1.09
# DS            0.40      0.14      0.13         0.05          0.67
# GB            2.55      0.98      1.70         0.23          5.19
# GBA           0.50      0.18      0.16         0.02          0.78
# GC            0.60      0.16      0.08         0.02          0.84
# GEN           1.95      0.63      0.26         0.12          2.67
# GG            0.00      0.00      0.04         0.00          0.04
# N64           1.02      0.36      0.27         0.05          1.60
# NES           2.04      0.48      2.05         0.10          4.16
# NG            0.00      0.00      0.23         0.00          0.23
# ...

# %% [markdown]
# 2. Strata 2: Genre Game
# <hr>

# %% [markdown]
# 2.1 Rata-rata dan standar deviasi

# %%
genre_strat.mean().sort_values(by='Global_Sales', ascending=False)
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Platform      0.504571  0.227573  0.147596     0.058228      0.938341
# Shooter       0.444733  0.239137  0.029221     0.078389      0.791885
# Role-Playing  0.219946  0.126384  0.236767     0.040060      0.623233
# Racing        0.287766  0.190865  0.045388     0.061865      0.586101
# Sports        0.291283  0.160635  0.057702     0.057532      0.567319
# Fighting      0.263667  0.119481  0.103007     0.043255      0.529375
# Action        0.264726  0.158323  0.048236     0.056508      0.528100
# Misc          0.235906  0.124198  0.061967     0.043312      0.465762
# Simulation    0.211430  0.130773  0.073472     0.036355      0.452364
# Puzzle        0.212680  0.087251  0.098471     0.021564      0.420876
# Strategy      0.100881  0.066579  0.072628     0.016681      0.257151
# Adventure     0.082271  0.049868  0.040490     0.013072      0.185879

# %%
genre_strat.std()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action        0.566890  0.407424  0.164835     0.239754      1.156427
# Adventure     0.274674  0.176454  0.120011     0.044704      0.513280
# Fighting      0.516148  0.253013  0.258908     0.105558      0.955965
# Misc          0.690878  0.446592  0.245602     0.143515      1.314886
# Platform      1.502039  0.588545  0.525242     0.166151      2.585254
# Puzzle        1.057669  0.318550  0.364745     0.070855      1.561716
# Racing        0.742523  0.581181  0.266680     0.271135      1.662437
# Role-Playing  0.672721  0.488864  0.647455     0.125165      1.707909
# Shooter       1.201147  0.549189  0.102398     0.199511      1.817263
# Simulation    0.466698  0.514097  0.303393     0.117133      1.195255
# Sports        1.041024  0.776772  0.223647     0.243892      2.089716
# Strategy      0.298956  0.192594  0.171460     0.041215      0.520908

# %% [markdown]
# 2.2 Percentile

# %%
genre.quantile([.1,.25,.5,.75,.9], interpolation='nearest')
# Out:
#           Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0.10     Action      0.00      0.00      0.00         0.00          0.02
# 0.25  Adventure      0.00      0.00      0.00         0.00          0.06
# 0.50     Puzzle      0.08      0.02      0.00         0.01          0.17
# 0.75    Shooter      0.24      0.11      0.04         0.04          0.47
# 0.90     Sports      0.61      0.35      0.18         0.11          1.21

# %% [markdown]
# 2.3 Ekstremum

# %%
genre.max()
# Out:
# Genre           Strategy
# NA_Sales           41.49
# EU_Sales           29.02
# JP_Sales           10.22
# Other_Sales        10.57
# Global_Sales       82.74
# dtype: object

# %%
genre.min()
# Out:
# Genre           Action
# NA_Sales           0.0
# EU_Sales           0.0
# JP_Sales           0.0
# Other_Sales        0.0
# Global_Sales      0.01
# dtype: object

# %% [markdown]
# 3. Strata 3: Studio/Publisher Game
# <hr>

# %% [markdown]
# 3.1 Rata-rata dan standar deviasi

# %%
# Mean
pub.mean()
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# 10TACLE Studios               0.023333  0.013333      0.00     0.000000
# 1C Company                    0.003333  0.023333      0.00     0.006667
# 20th Century Fox Video Games  0.364000  0.020000      0.00     0.002000
# 2D Boy                        0.000000  0.030000      0.00     0.010000
# 3DO                           0.180000  0.084444      0.00     0.017500
# ...                                ...       ...       ...          ...
# id Software                   0.020000  0.000000      0.00     0.000000
# imageepoch Inc.               0.000000  0.000000      0.02     0.000000
# inXile Entertainment          0.020000  0.060000      0.00     0.010000
# mixi, Inc                     0.000000  0.000000      0.86     0.000000
# responDESIGN                  0.045000  0.020000      0.00     0.005000
#
#                               Global_Sales
# Publisher
# ...

# %%
# Standar Deviasi
pub.std()
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# 10TACLE Studios               0.032146  0.015275  0.000000     0.000000
# 1C Company                    0.005774  0.011547  0.000000     0.005774
# 20th Century Fox Video Games  0.216171  0.012247  0.000000     0.004472
# 2D Boy                             NaN       NaN       NaN          NaN
# 3DO                           0.214849  0.071172  0.000000     0.016453
# ...                                ...       ...       ...          ...
# id Software                        NaN       NaN       NaN          NaN
# imageepoch Inc.               0.000000  0.000000  0.014142     0.000000
# inXile Entertainment               NaN       NaN       NaN          NaN
# mixi, Inc                          NaN       NaN       NaN          NaN
# responDESIGN                  0.035355  0.000000  0.000000     0.007071
#
#                               Global_Sales
# Publisher
# ...

# %% [markdown]
# 3.2 Persentil

# %%
pub_quant = pub.quantile([.1,.25,.5,.75,.9], interpolation='nearest')
with pd.option_context(
    'display.max_columns', None,
    'display.max_rows', None,
    'display.precision', 3,
):
    print(pub_quant)
# Out:
#                                              NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# 10TACLE Studios                        0.10      0.00      0.00      0.00
#                                        0.25      0.00      0.00      0.00
#                                        0.50      0.01      0.01      0.00
#                                        0.75      0.06      0.03      0.00
#                                        0.90      0.06      0.03      0.00
# 1C Company                             0.10      0.00      0.01      0.00
#                                        0.25      0.00      0.01      0.00
#                                        0.50      0.00      0.03      0.00
#                                        0.75      0.01      0.03      0.00
#                                        0.90      0.01      0.03      0.00
# 20th Century Fox Video Games           0.10      0.21      0.01      0.00
# ...

# %% [markdown]
# 3.3 Ekstremum

# %%
# nilai maksimum
pub.max().sort_values(by='Global_Sales', ascending=False)
# Out:
#                              NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                        41.49     29.02     10.22         8.46
# Microsoft Game Studios          14.97      4.94      0.24         1.67
# Take-Two Interactive             9.63      9.27      0.97        10.57
# Sony Computer Entertainment      6.85      5.09      3.28         7.53
# Activision                       9.67      6.21      0.65         2.52
# ...                               ...       ...       ...          ...
# UIG Entertainment                0.00      0.01      0.00         0.00
# Stainless Games                  0.01      0.01      0.00         0.00
# Epic Games                       0.01      0.00      0.00         0.00
# New World Computing              0.01      0.00      0.00         0.00
# Naxat Soft                       0.00      0.00      0.01         0.00
#
#                              Global_Sales
# Publisher
# Nintendo                            82.74
# ...

# %%
# nilai minimum
pub.min().sort_values(by="Global_Sales", ascending=True)
# Out:
#                       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Publisher
# Rebellion                 0.01      0.00      0.00         0.00          0.01
# Excalibur Publishing      0.00      0.01      0.00         0.00          0.01
# Experience Inc.           0.00      0.00      0.01         0.00          0.01
# Paradox Interactive       0.00      0.00      0.00         0.00          0.01
# Falcom Corporation        0.00      0.00      0.01         0.00          0.01
# ...                        ...       ...       ...          ...           ...
# Valve                     0.83      0.63      0.02         0.25          1.74
# Arena Entertainment       1.75      0.25      0.00         0.05          2.05
# UEP Systems               1.52      0.46      0.20         0.08          2.25
# Red Orb                   0.02      0.82      0.00         0.00          2.43
# Palcom                    3.38      0.44      0.31         0.04          4.17
#
# [578 rows x 5 columns]
